# %% [markdown]
# Deep Learning
# =============
#
# Assignment 4
# ------------
#
# Previously in `2_fullyconnected.ipynb` and `3_regularization.ipynb`, we trained fully connected networks to classify [notMNIST](http://yaroslavvb.blogspot.com/2011/09/notmnist-dataset.html) characters.
#
# The goal of this assignment is make the neural network convolutional.

# %%
# These are all the modules we'll be using later. Make sure you can import them
# before proceeding further.
from __future__ import print_function
import numpy as np
import tensorflow as tf
from six.moves import cPickle as pickle
from six.moves import range

# %%
pickle_file = 'notMNIST.pickle'

with open(pickle_file, 'rb') as f:
  save = pickle.load(f)
  train_dataset = save['train_dataset']
  train_labels = save['train_labels']
  valid_dataset = save['valid_dataset']
  valid_labels = save['valid_labels']
  test_dataset = save['test_dataset']
  test_labels = save['test_labels']
  del save  # hint to help gc free up memory
  print('Training set', train_dataset.shape, train_labels.shape)
  print('Validation set', valid_dataset.shape, valid_labels.shape)
  print('Test set', test_dataset.shape, test_labels.shape)
# Out:
# Training set (200000, 28, 28) (200000,)
# Validation set (10000, 28, 28) (10000,)
# Test set (10000, 28, 28) (10000,)

# %% [markdown]
# Reformat into a TensorFlow-friendly shape:
# - convolutions need the image data formatted as a cube (width by height by #channels)
# - labels as float 1-hot encodings.

# %%
image_size = 28
num_labels = 10
num_channels = 1 # grayscale

import numpy as np

def reformat(dataset, labels):
  dataset = dataset.reshape(
    (-1, image_size, image_size, num_channels)).astype(np.float32)
  labels = (np.arange(num_labels) == labels[:,None]).astype(np.float32)
  return dataset, labels
train_dataset, train_labels = reformat(train_dataset, train_labels)
valid_dataset, valid_labels = reformat(valid_dataset, valid_labels)
test_dataset, test_labels = reformat(test_dataset, test_labels)
print('Training set', train_dataset.shape, train_labels.shape)
print('Validation set', valid_dataset.shape, valid_labels.shape)
print('Test set', test_dataset.shape, test_labels.shape)
# Out:
# Training set (200000, 28, 28, 1) (200000, 10)
# Validation set (10000, 28, 28, 1) (10000, 10)
# Test set (10000, 28, 28, 1) (10000, 10)

# %%
def accuracy(predictions, labels):
  return (100.0 * np.sum(np.argmax(predictions, 1) == np.argmax(labels, 1))
          / predictions.shape[0])

# %% [markdown]
# Let's build a small network with two convolutional layers, followed by one fully connected layer. Convolutional networks are more expensive computationally, so we'll limit its depth and number of fully connected nodes.

# %%
batch_size = 16
patch_size = 5
depth = 16
num_hidden = 64

graph = tf.Graph()

with graph.as_default():

  # Input data.
  tf_train_dataset = tf.placeholder(
    tf.float32, shape=(batch_size, image_size, image_size, num_channels))
  tf_train_labels = tf.placeholder(tf.float32, shape=(batch_size, num_labels))
  tf_valid_dataset = tf.constant(valid_dataset)
  tf_test_dataset = tf.constant(test_dataset)
  
  # Variables.
  layer1_weights = tf.Variable(tf.truncated_normal(
      [patch_size, patch_size, num_channels, depth], stddev=0.1))
  layer1_biases = tf.Variable(tf.zeros([depth]))
  layer2_weights = tf.Variable(tf.truncated_normal(
      [patch_size, patch_size, depth, depth], stddev=0.1))
  layer2_biases = tf.Variable(tf.constant(1.0, shape=[depth]))
  layer3_weights = tf.Variable(tf.truncated_normal(
      [image_size // 4 * image_size // 4 * depth, num_hidden], stddev=0.1))
  layer3_biases = tf.Variable(tf.constant(1.0, shape=[num_hidden]))
  layer4_weights = tf.Variable(tf.truncated_normal(
      [num_hidden, num_labels], stddev=0.1))
  layer4_biases = tf.Variable(tf.constant(1.0, shape=[num_labels]))
  
  # Model.
  def model(data):
    conv = tf.nn.conv2d(data, layer1_weights, [1, 2, 2, 1], padding='SAME')
    hidden = tf.nn.relu(conv + layer1_biases)
    conv = tf.nn.conv2d(hidden, layer2_weights, [1, 2, 2, 1], padding='SAME')
    hidden = tf.nn.relu(conv + layer2_biases)
    shape = hidden.get_shape().as_list()
    reshape = tf.reshape(hidden, [shape[0], shape[1] * shape[2] * shape[3]])
    hidden = tf.nn.relu(tf.matmul(reshape, layer3_weights) + layer3_biases)
    return tf.matmul(hidden, layer4_weights) + layer4_biases
  
  # Training computation.
  logits = model(tf_train_dataset)
  loss = tf.reduce_mean(
    tf.nn.softmax_cross_entropy_with_logits(labels=tf_train_labels, logits=logits))
    
  # Optimizer.
  optimizer = tf.train.GradientDescentOptimizer(0.05).minimize(loss)
  
  # Predictions for the training, validation, and test data.
  train_prediction = tf.nn.softmax(logits)
  valid_prediction = tf.nn.softmax(model(tf_valid_dataset))
  test_prediction = tf.nn.softmax(model(tf_test_dataset))

# %%
num_steps = 1001

with tf.Session(graph=graph) as session:
  tf.global_variables_initializer().run()
  print('Initialized')
  for step in range(num_steps):
    offset = (step * batch_size) % (train_labels.shape[0] - batch_size)
    batch_data = train_dataset[offset:(offset + batch_size), :, :, :]
    batch_labels = train_labels[offset:(offset + batch_size), :]
    feed_dict = {tf_train_dataset : batch_data, tf_train_labels : batch_labels}
    _, l, predictions = session.run(
      [optimizer, loss, train_prediction], feed_dict=feed_dict)
    if (step % 50 == 0):
      print('Minibatch loss at step %d: %f' % (step, l))
      print('Minibatch accuracy: %.1f%%' % accuracy(predictions, batch_labels))
      print('Validation accuracy: %.1f%%' % accuracy(
        valid_prediction.eval(), valid_labels))
  print('Test accuracy: %.1f%%' % accuracy(test_prediction.eval(), test_labels))
# Out:
# Initialized
# Minibatch loss at step 0: 2.824483
# Minibatch accuracy: 6.2%
# Validation accuracy: 14.0%
# Minibatch loss at step 50: 1.768139
# Minibatch accuracy: 50.0%
# Validation accuracy: 57.2%
# Minibatch loss at step 100: 1.130366
# Minibatch accuracy: 62.5%
# Validation accuracy: 71.1%
# Minibatch loss at step 150: 0.791884
# Minibatch accuracy: 81.2%
# Validation accuracy: 77.0%
# Minibatch loss at step 200: 1.452137
# Minibatch accuracy: 62.5%
# Validation accuracy: 79.0%
# Minibatch loss at step 250: 0.198928
# Minibatch accuracy: 93.8%
# Validation accuracy: 79.4%
# Minibatch loss at step 300: 0.417147
# Minibatch accuracy: 81.2%
# Validation accuracy: 80.1%
# Minibatch loss at step 350: 0.279642
# Minibatch accuracy: 93.8%
# Validation accuracy: 79.6%
# Minibatch loss at step 400: 0.388061
# Minibatch accuracy: 87.5%
# Validation accuracy: 81.8%
# Minibatch loss at step 450: 0.873250
# Minibatch accuracy: 81.2%
# Validation accuracy: 80.9%
# Minibatch loss at step 500: 0.717341
# Minibatch accuracy: 81.2%
# Validation accuracy: 81.4%
# Minibatch loss at step 550: 0.454890
# Minibatch accuracy: 81.2%
# Validation accuracy: 82.2%
# Minibatch loss at step 600: 0.598732
# Minibatch accuracy: 81.2%
# Validation accuracy: 82.2%
# Minibatch loss at step 650: 0.311746
# Minibatch accuracy: 87.5%
# Validation accuracy: 82.3%
# Minibatch loss at step 700: 0.487530
# Minibatch accuracy: 93.8%
# Validation accuracy: 82.4%
# Minibatch loss at step 750: 0.602995
# Minibatch accuracy: 75.0%
# Validation accuracy: 83.2%
# Minibatch loss at step 800: 0.251596
# Minibatch accuracy: 93.8%
# Validation accuracy: 83.6%
# Minibatch loss at step 850: 0.250220
# Minibatch accuracy: 93.8%
# Validation accuracy: 83.6%
# Minibatch loss at step 900: 0.339998
# Minibatch accuracy: 87.5%
# Validation accuracy: 83.2%
# Minibatch loss at step 950: 0.520509
# Minibatch accuracy: 75.0%
# Validation accuracy: 83.6%
# Minibatch loss at step 1000: 0.035971
# Minibatch accuracy: 100.0%
# Validation accuracy: 83.7%
# Test accuracy: 89.2%

# %% [markdown]
# ---
# Problem 1
# ---------
#
# The convolutional model above uses convolutions with stride 2 to reduce the dimensionality. Replace the strides by a max pooling operation (`nn.max_pool()`) of stride 2 and kernel size 2.
#
# ---

# %%
batch_size = 16
patch_size = 5
depth = 16
num_hidden = 64

graph = tf.Graph()

with graph.as_default():

  # Input data.
  tf_train_dataset = tf.placeholder(
    tf.float32, shape=(batch_size, image_size, image_size, num_channels))
  tf_train_labels = tf.placeholder(tf.float32, shape=(batch_size, num_labels))
  tf_valid_dataset = tf.constant(valid_dataset)
  tf_test_dataset = tf.constant(test_dataset)
  
  # Variables.
  layer1_weights = tf.Variable(tf.truncated_normal(
      [patch_size, patch_size, num_channels, depth], stddev=0.1))
  layer1_biases = tf.Variable(tf.zeros([depth]))
  layer2_weights = tf.Variable(tf.truncated_normal(
      [patch_size, patch_size, depth, depth], stddev=0.1))
  layer2_biases = tf.Variable(tf.constant(1.0, shape=[depth]))
  layer3_weights = tf.Variable(tf.truncated_normal(
      [image_size // 4 * image_size // 4 * depth, num_hidden], stddev=0.1))
  layer3_biases = tf.Variable(tf.constant(1.0, shape=[num_hidden]))
  layer4_weights = tf.Variable(tf.truncated_normal(
      [num_hidden, num_labels], stddev=0.1))
  layer4_biases = tf.Variable(tf.constant(1.0, shape=[num_labels]))
  
  # Model.
  def model(data):
    conv = tf.nn.conv2d(data, layer1_weights, [1, 1, 1, 1], padding='SAME')
    max_pool = tf.nn.max_pool(conv, [1, 2, 2, 1], [1, 2, 2, 1], padding='SAME')
    hidden = tf.nn.relu(max_pool + layer1_biases)
    conv = tf.nn.conv2d(hidden, layer2_weights, [1, 1, 1, 1], padding='SAME')
    max_pool = tf.nn.max_pool(conv, [1, 2, 2, 1], [1, 2, 2, 1], padding='SAME')
    hidden = tf.nn.relu(max_pool + layer2_biases)
    shape = hidden.get_shape().as_list()
    reshape = tf.reshape(hidden, [shape[0], shape[1] * shape[2] * shape[3]])
    hidden = tf.nn.relu(tf.matmul(reshape, layer3_weights) + layer3_biases)
    return tf.matmul(hidden, layer4_weights) + layer4_biases
  
  # Training computation.
  logits = model(tf_train_dataset)
  loss = tf.reduce_mean(
    tf.nn.softmax_cross_entropy_with_logits(labels=tf_train_labels, logits=logits))
    
  # Optimizer.
  optimizer = tf.train.GradientDescentOptimizer(0.05).minimize(loss)
  
  # Predictions for the training, validation, and test data.
  train_prediction = tf.nn.softmax(logits)
  valid_prediction = tf.nn.softmax(model(tf_valid_dataset))
  test_prediction = tf.nn.softmax(model(tf_test_dataset))

# %%
num_steps = 1001

with tf.Session(graph=graph) as session:
  tf.global_variables_initializer().run()
  print('Initialized')
  for step in range(num_steps):
    offset = (step * batch_size) % (train_labels.shape[0] - batch_size)
    batch_data = train_dataset[offset:(offset + batch_size), :, :, :]
    batch_labels = train_labels[offset:(offset + batch_size), :]
    feed_dict = {tf_train_dataset : batch_data, tf_train_labels : batch_labels}
    _, l, predictions = session.run(
      [optimizer, loss, train_prediction], feed_dict=feed_dict)
    if (step % 50 == 0):
      print('Minibatch loss at step %d: %f' % (step, l))
      print('Minibatch accuracy: %.1f%%' % accuracy(predictions, batch_labels))
      print('Validation accuracy: %.1f%%' % accuracy(
        valid_prediction.eval(), valid_labels))
  print('Test accuracy: %.1f%%' % accuracy(test_prediction.eval(), test_labels))
# Out:
# Initialized
# Minibatch loss at step 0: 3.831188
# Minibatch accuracy: 6.2%
# Validation accuracy: 8.8%
# Minibatch loss at step 50: 1.762868
# Minibatch accuracy: 43.8%
# Validation accuracy: 47.1%
# Minibatch loss at step 100: 1.221391
# Minibatch accuracy: 50.0%
# Validation accuracy: 60.7%
# Minibatch loss at step 150: 0.998943
# Minibatch accuracy: 81.2%
# Validation accuracy: 75.6%
# Minibatch loss at step 200: 1.755985
# Minibatch accuracy: 56.2%
# Validation accuracy: 75.3%
# Minibatch loss at step 250: 0.237635
# Minibatch accuracy: 93.8%
# Validation accuracy: 80.3%
# Minibatch loss at step 300: 0.336354
# Minibatch accuracy: 93.8%
# Validation accuracy: 80.4%
# Minibatch loss at step 350: 0.283217
# Minibatch accuracy: 93.8%
# Validation accuracy: 82.1%
# Minibatch loss at step 400: 0.369752
# Minibatch accuracy: 93.8%
# Validation accuracy: 82.8%
# Minibatch loss at step 450: 0.918183
# Minibatch accuracy: 81.2%
# Validation accuracy: 82.2%
# Minibatch loss at step 500: 0.714514
# Minibatch accuracy: 81.2%
# Validation accuracy: 82.5%
# Minibatch loss at step 550: 0.396268
# Minibatch accuracy: 87.5%
# Validation accuracy: 83.3%
# Minibatch loss at step 600: 0.426466
# Minibatch accuracy: 81.2%
# Validation accuracy: 82.8%
# Minibatch loss at step 650: 0.634992
# Minibatch accuracy: 81.2%
# Validation accuracy: 84.3%
# Minibatch loss at step 700: 0.465055
# Minibatch accuracy: 87.5%
# Validation accuracy: 84.2%
# Minibatch loss at step 750: 0.676214
# Minibatch accuracy: 81.2%
# Validation accuracy: 84.2%
# Minibatch loss at step 800: 0.234829
# Minibatch accuracy: 93.8%
# Validation accuracy: 84.7%
# Minibatch loss at step 850: 0.280125
# Minibatch accuracy: 93.8%
# Validation accuracy: 85.4%
# Minibatch loss at step 900: 0.279673
# Minibatch accuracy: 93.8%
# Validation accuracy: 84.2%
# Minibatch loss at step 950: 0.297449
# Minibatch accuracy: 93.8%
# Validation accuracy: 84.5%
# Minibatch loss at step 1000: 0.050123
# Minibatch accuracy: 100.0%
# Validation accuracy: 85.2%
# Test accuracy: 90.7%

# %% [markdown]
# ---
# Problem 2
# ---------
#
# Try to get the best performance you can using a convolutional net. Look for example at the classic [LeNet5](http://yann.lecun.com/exdb/lenet/) architecture, adding Dropout, and/or adding learning rate decay.
#
# ---

# %%
batch_size = 16
patch_size = 5
depth = 16
num_hidden = 64

graph = tf.Graph()

with graph.as_default():

  # Input data.
  tf_train_dataset = tf.placeholder(
    tf.float32, shape=(batch_size, image_size, image_size, num_channels))
  tf_train_labels = tf.placeholder(tf.float32, shape=(batch_size, num_labels))
  tf_valid_dataset = tf.constant(valid_dataset)
  tf_test_dataset = tf.constant(test_dataset)
  
  # Variables.
  layer1_weights = tf.Variable(tf.truncated_normal(
      [patch_size, patch_size, num_channels, depth], stddev=0.1))
  layer1_biases = tf.Variable(tf.zeros([depth]))
  layer2_weights = tf.Variable(tf.truncated_normal(
      [patch_size, patch_size, depth, depth], stddev=0.1))
  layer2_biases = tf.Variable(tf.constant(1.0, shape=[depth]))
  layer3_weights = tf.Variable(tf.truncated_normal(
      [image_size // 4 * image_size // 4 * depth, num_hidden], stddev=0.1))
  layer3_biases = tf.Variable(tf.constant(1.0, shape=[num_hidden]))
  layer4_weights = tf.Variable(tf.truncated_normal(
      [num_hidden, num_labels], stddev=0.1))
  layer4_biases = tf.Variable(tf.constant(1.0, shape=[num_labels]))
  
  # Model.
  def model(data):
    conv = tf.nn.conv2d(data, layer1_weights, [1, 1, 1, 1], padding='SAME')
    hidden = tf.nn.relu(conv + layer1_biases)
    max_pool = tf.nn.max_pool(hidden, [1, 2, 2, 1], [1, 2, 2, 1], padding='SAME')
    
    dropout = tf.nn.dropout(max_pool, 0.8)
    
    conv = tf.nn.conv2d(dropout, layer2_weights, [1, 1, 1, 1], padding='SAME')
    hidden = tf.nn.relu(conv + layer2_biases)
    max_pool = tf.nn.max_pool(hidden, [1, 2, 2, 1], [1, 2, 2, 1], padding='SAME')
    
    shape = max_pool.get_shape().as_list()
    reshape = tf.reshape(max_pool, [shape[0], shape[1] * shape[2] * shape[3]])
    
    hidden = tf.nn.relu(tf.matmul(reshape, layer3_weights) + layer3_biases)
    return tf.matmul(hidden, layer4_weights) + layer4_biases
  
  # Training computation.
  logits = model(tf_train_dataset)
  loss = tf.reduce_mean(
    tf.nn.softmax_cross_entropy_with_logits(labels=tf_train_labels, logits=logits))
    
  # Optimizer.
  optimizer = tf.train.GradientDescentOptimizer(0.05).minimize(loss)
  
  # Predictions for the training, validation, and test data.
  train_prediction = tf.nn.softmax(logits)
  valid_prediction = tf.nn.softmax(model(tf_valid_dataset))
  test_prediction = tf.nn.softmax(model(tf_test_dataset))

# %%
num_steps = 5001

with tf.Session(graph=graph) as session:
  tf.global_variables_initializer().run()
  print('Initialized')
  for step in range(num_steps):
    offset = (step * batch_size) % (train_labels.shape[0] - batch_size)
    batch_data = train_dataset[offset:(offset + batch_size), :, :, :]
    batch_labels = train_labels[offset:(offset + batch_size), :]
    feed_dict = {tf_train_dataset : batch_data, tf_train_labels : batch_labels}
    _, l, predictions = session.run(
      [optimizer, loss, train_prediction], feed_dict=feed_dict)
    if (step % 50 == 0):
      print('Minibatch loss at step %d: %f' % (step, l))
      print('Minibatch accuracy: %.1f%%' % accuracy(predictions, batch_labels))
      print('Validation accuracy: %.1f%%' % accuracy(
        valid_prediction.eval(), valid_labels))
  print('Test accuracy: %.1f%%' % accuracy(test_prediction.eval(), test_labels))
# Out:
# Initialized
# Minibatch loss at step 0: 2.907175
# Minibatch accuracy: 12.5%
# Validation accuracy: 10.0%
# Minibatch loss at step 50: 2.119904
# Minibatch accuracy: 37.5%
# Validation accuracy: 33.6%
# Minibatch loss at step 100: 1.382648
# Minibatch accuracy: 50.0%
# Validation accuracy: 56.7%
# Minibatch loss at step 150: 0.879002
# Minibatch accuracy: 75.0%
# Validation accuracy: 72.7%
# Minibatch loss at step 200: 1.421676
# Minibatch accuracy: 56.2%
# Validation accuracy: 72.3%
# Minibatch loss at step 250: 0.450708
# Minibatch accuracy: 81.2%
# Validation accuracy: 77.7%
# Minibatch loss at step 300: 0.398144
# Minibatch accuracy: 87.5%
# Validation accuracy: 78.8%
# Minibatch loss at step 350: 0.334783
# Minibatch accuracy: 93.8%
# Validation accuracy: 79.4%
# Minibatch loss at step 400: 0.546809
# Minibatch accuracy: 75.0%
# Validation accuracy: 80.5%
# Minibatch loss at step 450: 0.833270
# Minibatch accuracy: 81.2%
# Validation accuracy: 79.8%
# Minibatch loss at step 500: 0.875458
# Minibatch accuracy: 68.8%
# Validation accuracy: 80.9%
# Minibatch loss at step 550: 0.397666
# Minibatch accuracy: 87.5%
# Validation accuracy: 82.0%
# Minibatch loss at step 600: 0.606102
# Minibatch accuracy: 75.0%
# Validation accuracy: 81.9%
# Minibatch loss at step 650: 0.476702
# Minibatch accuracy: 81.2%
# Validation accuracy: 82.5%
# Minibatch loss at step 700: 0.455076
# Minibatch accuracy: 93.8%
# Validation accuracy: 83.3%
# Minibatch loss at step 750: 0.581754
# Minibatch accuracy: 81.2%
# Validation accuracy: 82.8%
# Minibatch loss at step 800: 0.221931
# Minibatch accuracy: 93.8%
# Validation accuracy: 83.6%
# Minibatch loss at step 850: 0.352792
# Minibatch accuracy: 93.8%
# Validation accuracy: 84.2%
# Minibatch loss at step 900: 0.393010
# Minibatch accuracy: 87.5%
# Validation accuracy: 83.9%
# Minibatch loss at step 950: 0.456837
# Minibatch accuracy: 87.5%
# Validation accuracy: 83.5%
# Minibatch loss at step 1000: 0.073343
# Minibatch accuracy: 100.0%
# Validation accuracy: 83.7%
# Minibatch loss at step 1050: 0.575513
# Minibatch accuracy: 81.2%
# Validation accuracy: 83.3%
# Minibatch loss at step 1100: 0.577403
# Minibatch accuracy: 81.2%
# Validation accuracy: 84.0%
# Minibatch loss at step 1150: 0.465159
# Minibatch accuracy: 87.5%
# Validation accuracy: 84.0%
# Minibatch loss at step 1200: 0.098084
# Minibatch accuracy: 100.0%
# Validation accuracy: 84.2%
# Minibatch loss at step 1250: 0.344519
# Minibatch accuracy: 93.8%
# Validation accuracy: 84.7%
# Minibatch loss at step 1300: 0.324612
# Minibatch accuracy: 93.8%
# Validation accuracy: 84.9%
# Minibatch loss at step 1350: 0.135455
# Minibatch accuracy: 93.8%
# Validation accuracy: 84.8%
# Minibatch loss at step 1400: 0.449109
# Minibatch accuracy: 87.5%
# Validation accuracy: 85.2%
# Minibatch loss at step 1450: 0.762599
# Minibatch accuracy: 81.2%
# Validation accuracy: 85.0%
# Minibatch loss at step 1500: 0.711357
# Minibatch accuracy: 81.2%
# Validation accuracy: 85.9%
# Minibatch loss at step 1550: 0.344577
# Minibatch accuracy: 87.5%
# Validation accuracy: 85.0%
# Minibatch loss at step 1600: 0.336480
# Minibatch accuracy: 93.8%
# Validation accuracy: 85.7%
# Minibatch loss at step 1650: 1.035766
# Minibatch accuracy: 68.8%
# Validation accuracy: 86.0%
# Minibatch loss at step 1700: 0.780697
# Minibatch accuracy: 75.0%
# Validation accuracy: 85.2%
# Minibatch loss at step 1750: 0.229796
# Minibatch accuracy: 93.8%
# Validation accuracy: 85.3%
# Minibatch loss at step 1800: 0.869185
# Minibatch accuracy: 75.0%
# Validation accuracy: 86.0%
# Minibatch loss at step 1850: 0.232575
# Minibatch accuracy: 93.8%
# Validation accuracy: 85.8%
# Minibatch loss at step 1900: 0.579744
# Minibatch accuracy: 75.0%
# Validation accuracy: 84.6%
# Minibatch loss at step 1950: 0.363330
# Minibatch accuracy: 93.8%
# Validation accuracy: 85.6%
# Minibatch loss at step 2000: 0.595520
# Minibatch accuracy: 87.5%
# Validation accuracy: 86.3%
# Minibatch loss at step 2050: 0.373329
# Minibatch accuracy: 87.5%
# Validation accuracy: 86.2%
# Minibatch loss at step 2100: 0.457379
# Minibatch accuracy: 87.5%
# Validation accuracy: 86.3%
# Minibatch loss at step 2150: 0.336836
# Minibatch accuracy: 93.8%
# Validation accuracy: 86.4%
# Minibatch loss at step 2200: 0.231656
# Minibatch accuracy: 100.0%
# Validation accuracy: 86.2%
# Minibatch loss at step 2250: 0.859804
# Minibatch accuracy: 75.0%
# Validation accuracy: 86.7%
# Minibatch loss at step 2300: 0.599935
# Minibatch accuracy: 87.5%
# Validation accuracy: 86.6%
# Minibatch loss at step 2350: 0.127828
# Minibatch accuracy: 93.8%
# Validation accuracy: 86.8%
# Minibatch loss at step 2400: 0.904568
# Minibatch accuracy: 75.0%
# Validation accuracy: 86.4%
# Minibatch loss at step 2450: 0.037740
# Minibatch accuracy: 100.0%
# Validation accuracy: 86.4%
# Minibatch loss at step 2500: 0.578814
# Minibatch accuracy: 87.5%
# Validation accuracy: 87.3%
# Minibatch loss at step 2550: 0.098988
# Minibatch accuracy: 100.0%
# Validation accuracy: 87.3%
# Minibatch loss at step 2600: 0.205276
# Minibatch accuracy: 93.8%
# Validation accuracy: 86.8%
# Minibatch loss at step 2650: 0.216532
# Minibatch accuracy: 87.5%
# Validation accuracy: 87.0%
# Minibatch loss at step 2700: 0.586811
# Minibatch accuracy: 81.2%
# Validation accuracy: 86.8%
# Minibatch loss at step 2750: 0.576029
# Minibatch accuracy: 87.5%
# Validation accuracy: 86.5%
# Minibatch loss at step 2800: 0.140673
# Minibatch accuracy: 100.0%
# Validation accuracy: 87.0%
# Minibatch loss at step 2850: 0.551402
# Minibatch accuracy: 87.5%
# Validation accuracy: 86.0%
# Minibatch loss at step 2900: 0.351671
# Minibatch accuracy: 87.5%
# Validation accuracy: 86.7%
# Minibatch loss at step 2950: 0.337142
# Minibatch accuracy: 87.5%
# Validation accuracy: 86.9%
# Minibatch loss at step 3000: 0.142517
# Minibatch accuracy: 100.0%
# Validation accuracy: 86.6%
# Minibatch loss at step 3050: 0.351202
# Minibatch accuracy: 87.5%
# Validation accuracy: 87.0%
# Minibatch loss at step 3100: 0.535714
# Minibatch accuracy: 87.5%
# Validation accuracy: 86.7%
# Minibatch loss at step 3150: 0.206108
# Minibatch accuracy: 93.8%
# Validation accuracy: 87.5%
# Minibatch loss at step 3200: 0.099445
# Minibatch accuracy: 100.0%
# Validation accuracy: 87.7%
# Minibatch loss at step 3250: 0.547229
# Minibatch accuracy: 75.0%
# Validation accuracy: 87.7%
# Minibatch loss at step 3300: 0.715523
# Minibatch accuracy: 81.2%
# Validation accuracy: 87.0%
# Minibatch loss at step 3350: 0.420972
# Minibatch accuracy: 87.5%
# Validation accuracy: 87.4%
# Minibatch loss at step 3400: 0.359247
# Minibatch accuracy: 87.5%
# Validation accuracy: 87.8%
# Minibatch loss at step 3450: 0.547191
# Minibatch accuracy: 87.5%
# Validation accuracy: 87.5%
# Minibatch loss at step 3500: 0.576617
# Minibatch accuracy: 81.2%
# Validation accuracy: 86.8%
# Minibatch loss at step 3550: 0.296982
# Minibatch accuracy: 93.8%
# Validation accuracy: 87.7%
# Minibatch loss at step 3600: 0.382737
# Minibatch accuracy: 87.5%
# Validation accuracy: 88.0%
# Minibatch loss at step 3650: 0.612509
# Minibatch accuracy: 75.0%
# Validation accuracy: 87.9%
# Minibatch loss at step 3700: 0.096492
# Minibatch accuracy: 100.0%
# Validation accuracy: 87.3%
# Minibatch loss at step 3750: 0.527382
# Minibatch accuracy: 87.5%
# Validation accuracy: 88.0%
# Minibatch loss at step 3800: 0.307961
# Minibatch accuracy: 93.8%
# Validation accuracy: 87.5%
# Minibatch loss at step 3850: 0.176510
# Minibatch accuracy: 93.8%
# Validation accuracy: 87.7%
# Minibatch loss at step 3900: 0.663840
# Minibatch accuracy: 81.2%
# Validation accuracy: 87.6%
# Minibatch loss at step 3950: 0.288941
# Minibatch accuracy: 93.8%
# Validation accuracy: 87.3%
# Minibatch loss at step 4000: 0.172081
# Minibatch accuracy: 93.8%
# Validation accuracy: 88.0%
# Minibatch loss at step 4050: 0.396338
# Minibatch accuracy: 87.5%
# Validation accuracy: 88.2%
# Minibatch loss at step 4100: 0.282750
# Minibatch accuracy: 93.8%
# Validation accuracy: 88.0%
# Minibatch loss at step 4150: 0.145962
# Minibatch accuracy: 100.0%
# Validation accuracy: 88.3%
# Minibatch loss at step 4200: 0.009433
# Minibatch accuracy: 100.0%
# Validation accuracy: 87.9%
# Minibatch loss at step 4250: 0.369084
# Minibatch accuracy: 93.8%
# Validation accuracy: 87.8%
# Minibatch loss at step 4300: 0.438554
# Minibatch accuracy: 87.5%
# Validation accuracy: 87.6%
# Minibatch loss at step 4350: 0.463774
# Minibatch accuracy: 87.5%
# Validation accuracy: 87.7%
# Minibatch loss at step 4400: 0.609162
# Minibatch accuracy: 87.5%
# Validation accuracy: 87.8%
# Minibatch loss at step 4450: 0.191118
# Minibatch accuracy: 93.8%
# Validation accuracy: 88.0%
# Minibatch loss at step 4500: 0.545447
# Minibatch accuracy: 81.2%
# Validation accuracy: 87.7%
# Minibatch loss at step 4550: 0.323683
# Minibatch accuracy: 87.5%
# Validation accuracy: 88.1%
# Minibatch loss at step 4600: 0.538323
# Minibatch accuracy: 81.2%
# Validation accuracy: 87.1%
# Minibatch loss at step 4650: 0.242263
# Minibatch accuracy: 87.5%
# Validation accuracy: 88.0%
# Minibatch loss at step 4700: 0.699253
# Minibatch accuracy: 93.8%
# Validation accuracy: 88.3%
# Minibatch loss at step 4750: 0.456567
# Minibatch accuracy: 81.2%
# Validation accuracy: 88.2%
# Minibatch loss at step 4800: 0.123371
# Minibatch accuracy: 93.8%
# Validation accuracy: 88.3%
# Minibatch loss at step 4850: 0.212203
# Minibatch accuracy: 87.5%
# Validation accuracy: 87.7%
# Minibatch loss at step 4900: 0.194769
# Minibatch accuracy: 93.8%
# Validation accuracy: 88.1%
# Minibatch loss at step 4950: 0.837222
# Minibatch accuracy: 81.2%
# Validation accuracy: 88.3%
# Minibatch loss at step 5000: 0.469618
# Minibatch accuracy: 81.2%
# Validation accuracy: 88.1%
# Test accuracy: 93.4%
